# %% [markdown]
# # Artifact Insertion from Supabase

# %%
import os
import random
from supabase import create_client
from datetime import datetime
from dotenv import load_dotenv
from main import process_artifact
from nodes import ArtifactNode

load_dotenv()
# Out:
# True

# %%
TABLE = "artifacts"
USERS = [
    "497cf09f-fa20-4a41-a5f2-457503b7a4ad",
    "d8f75ac4-dcd3-4fe7-8813-72b298bf5baa",
    "12eb2c3c-3b98-4750-a4f4-7febe4af977b",
    "75a2ec64-d909-4999-abd8-d4ccd8fc7854",
    "ed273c28-a23b-4e6f-b184-5387ec40cfc6",
]

# %% [markdown]
# ## Supabase client

# %%
SUPABASE_URL = os.getenv("SUPABASE_URL")
SUPABASE_API_KEY = os.getenv("SUPABASE_API_KEY")

supabase = create_client(SUPABASE_URL, SUPABASE_API_KEY)

def get_artifacts_from_supabase(date: str):
    """Obtiene todos los artifacts de la tabla 'artifacts' en Supabase para un día específico"""

    try:
        date_obj = datetime.strptime(date, "%Y-%m-%d")
    except ValueError:
        raise Exception("Invalid date format. Please use YYYY-MM-DD.")
    
    response = supabase.table(TABLE).select("id, code, user_id").filter("created_at", "gte", date).execute()
    return response.data

# %%
get_artifacts_from_supabase("2025-04-03")
# Out:
# [{'id': '47a81ad7-b98d-41cf-aa86-087e164d5aa9',
#   'code': '\nimport React from \'react\';\nimport { LineChart, Line, XAxis, YAxis, CartesianGrid, Tooltip, ResponsiveContainer } from \'recharts\';\n\nconst data = [\n  { dia: 0, mortalidadAcumulada: 0 },\n  { dia: 1, mortalidadAcumulada: 40 },\n  { dia: 2, mortalidadAcumulada: 60 },\n  { dia: 3, mortalidadAcumulada: 96 },\n  { dia: 4, mortalidadAcumulada: 117 },\n  { dia: 5, mortalidadAcumulada: 143 },\n  { dia: 6, mortalidadAcumulada: 191 },\n  { dia: 7, mortalidadAcumulada: 206 },\n  { dia: 8, mortalidadAcumulada: 224 },\n  { dia: 9, mortalidadAcumulada: 239 },\n  { dia: 10, mortalidadAcumulada: 241 },\n  { dia: 11, mortalidadAcumulada: 253 },\n  { dia: 12, mortalidadAcumulada: 263 },\n  { dia: 13, mortalidadAcumulada: 270 },\n  { dia: 14, mortalidadAcumulada: 280 },\n  { dia: 15, mortalidadAcumulada: 290 },\n  { dia: 16, mortalidadAcumulada: 308 },\n  { dia: 17, mortalidadAcumulada: 318 },\n  { dia: 18, mortalidadAcumulada: 331 },\n  { dia: 19, mortalidadAcumulada: 341 },\n  { dia: 20, mortalidadAcumulada: 348 },\n  { dia: 21, mortalidadAcumulada: 355 },\n  { dia: 22, mortalidadAcumulada: 365 },\n  { dia: 23, mortalidadAcumulada: 377 },\n  { dia: 24, mortalidadAcumulada: 383 },\n  { dia: 25, mortalidadAcumulada: 389 },\n  { dia: 26, mortalidadAcumulada: 396 },\n  { dia: 27, mortalidadAcumulada: 406 },\n  { dia: 28, mortalidadAcumulada: 419 },\n  { dia: 29, mortalidadAcumulada: 427 },\n  { dia: 30, mortalidadAcumulada: 438 },\n  { dia: 31, mortalidadAcumulada: 448 },\n  { dia: 32, mortalidadAcumulada: 455 },\n  { dia: 33, mortalidadAcumulada: 461 },\n  { dia: 34, mortalidadAcumulada: 465 },\n  { dia: 35, mortalidadAcumulada: 469 },\n  { dia: 36, mortalidadAcumulada: 475 },\n  { dia: 37, mortalidadAcumulada: 479 },\n  { dia: 38, mortalidadAcumulada: 495 },\n  { dia: 39, mortalidadAcumulada: 512 },\n  { dia: 40, mortalidadAcumulada: 524 },\n  { dia: 41, mortalidadAcumulada: 529 },\n  { dia: 42, mortalidadAcumulada: 534 },\n  { dia: 43, mortalidadAcumulada: 597 },\n  { dia: 44, mortalidadAcumulada: 597 }\n];\n\nconst MortalidadAcumuladaGrafico = () => {\n  return (\n    <div className="flex flex-col items-center justify-center w-full" style={{\n      padding: \'0.5vh 0.5vw\',\n      overflow: \'visible\',\n      maxWidth: \'100%\',\n      maxHeight: \'100%\'\n    }}>\n      <h2 style={{\n        fontSize: \'min(3vw, 16px)\',\n        fontWeight: \'bold\',\n        marginBottom: \'min(1vh, 8px)\',\n        textAlign: \'center\',\n        whiteSpace: \'nowrap\'\n      }}>Mortalidad Acumulada en Pabellón 3 - Bosque Viejo</h2>\n\n      <div style={{\n        width: \'100%\',\n        height: \'min(80vh, 400px)\',\n        minHeight: \'150px\'\n      }}>\n        <ResponsiveContainer width="100%" height="100%">\n          <LineChart \n            data={data}\n            margin={{ top: 10, right: 10, left: 5, bottom: 20 }}\n          >\n            <CartesianGrid strokeDasharray="3 3" />\n            <XAxis \n              dataKey="dia" \n              tick={{ fontSize: \'min(2vw, 10px)\' }}\n              label={{ \n                value: \'Día\', \n                position: \'insideBottom\', \n                offset: -5, \n                fontSize: \'min(2vw, 12px)\',\n                style: { textAnchor: \'middle\' }\n              }}\n            />\n            <YAxis \n              tick={{ fontSize: \'min(2vw, 10px)\' }}\n              label={{\n                value: \'Mortalidad Acumulada\',\n                angle: -90,\n                position: \'insideLeft\',\n                style: { textAnchor: \'middle\' },\n                fontSize: \'min(2vw, 12px)\'\n              }}\n            />\n            <Tooltip \n              formatter={(value) => [`${value}`, \'Mortalidad\']}\n              contentStyle={{ fontSize: \'min(2vw, 12px)\' }}\n            />\n            <Line \n              type="monotone" \n              dataKey="mortalidadAcumulada" \n              stroke="#8884d8" \n              strokeWidth={1.5}\n    ...
#   'user_id': '71874759-2026-4e9c-8d0e-7456b87f4133'},
#  {'id': '447b3c24-9622-4b96-b1df-52d5158a2212',
#   'code': '\nimport React from \'react\';\n\nconst HolaComponent = () => {\n  return (\n    <div className="flex items-center justify-center min-h-screen">\n      <h1 className="text-2xl font-bold">Hola</h1>\n    </div>\n  );\n};\n\nexport default HolaComponent;\n',
#   'user_id': '71874759-2026-4e9c-8d0e-7456b87f4133'},
#  {'id': '3457310a-861f-4e0f-9166-2d20aa6acbd0',
#   'code': 'import React, { useState, useEffect } from \'react\';\nimport { LineChart, Line, BarChart, Bar, PieChart, Pie, AreaChart, Area, XAxis, YAxis, CartesianGrid, Tooltip, Legend, ResponsiveContainer, ComposedChart, Cell, LabelList } from \'recharts\';\nimport { Gauge, Truck, BarChart as BarChartIcon, AlertCircle, Clock, RefreshCw, Calendar, ArrowUp, ArrowDown } from \'lucide-react\';\n\n// Configuración de la API\nconst API_URL = \'https://api-control-tower.replit.app\';\n\nconst PlantasAlimentosDashboard = () => {\n  // Estados para almacenar datos\n  const [datosRendimiento, setDatosRendimiento] = useState(null);\n  const [datosStock, setDatosStock] = useState(null);\n  const [datosCumplimientoDespacho, setDatosCumplimientoDespacho] = useState(null);\n  const [datosCumplimientoEntrega, setDatosCumplimientoEntrega] = useState(null);\n  const [loading, setLoading] = useState(true);\n  const [ultimaActualizacion, setUltimaActualizacion] = useState(new Date());\n\n  // Cargar datos de la API\n  useEffect(() => {\n    const cargarDatos = async () => {\n      setLoading(true);\n      \n      try {\n        // Realizar llamadas a la API\n        const fetchRendimiento = fetch(`${API_URL}/api/rendimiento-plantas`)\n          .then(res => res.json())\n          .catch(err => {\n            console.error("Error al cargar datos de rendimiento:", err);\n            return null;\n          });\n          \n        const fetchStock = fetch(`${API_URL}/api/stock-plantas`)\n          .then(res => res.json())\n          .catch(err => {\n            console.error("Error al cargar datos de stock:", err);\n            return null;\n          });\n          \n        const fetchCumplimientoDespacho = fetch(`${API_URL}/api/cumplimiento-despacho`)\n          .then(res => res.json())\n          .catch(err => {\n            console.error("Error al cargar datos de cumplimiento de despacho:", err);\n            return null;\n          });\n          \n        const fetchCumplimientoEntrega = fetch(`${API_URL}/api/cumplimiento-entrega`)\n          .then(res => res.json())\n          .catch(err => {\n            console.error("Error al cargar datos de cumplimiento de entrega:", err);\n            return null;\n          });\n        \n        // Esperar a que todas las llamadas terminen\n        const [rendimiento, stock, cumplimientoDespacho, cumplimientoEntrega] = \n          await Promise.all([fetchRendimiento, fetchStock, fetchCumplimientoDespacho, fetchCumplimientoEntrega]);\n        \n        // Actualizar estados con los datos obtenidos\n        if (rendimiento) setDatosRendimiento(rendimiento);\n        if (stock) setDatosStock(stock);\n        if (cumplimientoDespacho) setDatosCumplimientoDespacho(cumplimientoDespacho);\n        if (cumplimientoEntrega) setDatosCumplimientoEntrega(cumplimientoEntrega);\n        \n        setUltimaActualizacion(new Date());\n        \n      } catch (error) {\n        console.error("Error al cargar datos:", error);\n      } finally {\n        setLoading(false);\n      }\n    };\n    \n    cargarDatos();\n    \n    // Actualizar cada 5 minutos\n    const intervalo = setInterval(cargarDatos, 300000);\n    \n    return () => clearInterval(intervalo);\n  }, []);\n\n  // Función para obtener color según porcentaje\n  const getColorPorcentaje = (porcentaje) => {\n    if (porcentaje >= 90) return \'#10b981\'; // Verde\n    if (porcentaje >= 70) return \'#f59e0b\'; // Amarillo\n    return \'#ef4444\'; // Rojo\n  };\n  \n  // Función para formatear números\n  const formatoNumero = (numero, decimales = 0) => {\n    if (numero === undefined || numero === null) return \'0\';\n    return Number(numero).toFixed(decimales);\n  };\n\n  // Mostrar spinner de carga\n  if (loading && !datosRendimiento && !datosStock && !datosCumplimientoDespacho && !datosCumplimientoEntrega) {\n    return (\n      <div className="flex items-center justify-center min-h-screen w-full bg-gray-900 text-white p-4">\n        <div className="animate ...
#   'user_id': '71874759-2026-4e9c-8d0e-7456b87f4133'},
#  {'id': '9648cadb-becb-4b7c-b264-ba49e250971b',
#   'code': 'import React, { useState, useEffect } from \'react\';\nimport { LineChart, Line, BarChart, Bar, PieChart, Pie, AreaChart, Area, XAxis, YAxis, CartesianGrid, Tooltip, Legend, ResponsiveContainer, ComposedChart, Cell, LabelList } from \'recharts\';\nimport { Ship, TrendingUp, Truck, AlertCircle, Clock, Package, BarChart as BarChartIcon, PieChart as PieChartIcon, RefreshCw, Calendar, Sliders, Zap, CheckCircle, AlertTriangle, ArrowUpRight, ArrowDownRight } from \'lucide-react\';\n\n// Configuración de la API\nconst API_URL = \'https://api-control-tower.replit.app\';\n\nconst LogisticaDashboard = () => {\n  // Estados para almacenar datos\n  const [datosBarcos, setDatosBarcos] = useState(null);\n  const [datosEnvios, setDatosEnvios] = useState(null);\n  const [datosLineup, setDatosLineup] = useState(null);\n  const [loading, setLoading] = useState(true);\n  const [periodoSeleccionado, setPeriodoSeleccionado] = useState(\'semanal\');\n  const [puertoSeleccionado, setPuertoSeleccionado] = useState(\'San Antonio\');\n  const [vistaActual, setVistaActual] = useState(\'dashboard\');\n  const [anomaliasDetectadas, setAnomaliasDetectadas] = useState([]);\n  const [modoSimulacion, setModoSimulacion] = useState(false);\n  const [parametrosSimulacion, setParametrosSimulacion] = useState({\n    ritmoDescarga: 0,\n    capacidadTransporte: 0,\n    eficienciaDespacho: 0,\n    factorClimatico: 0\n  });\n\n  // Cargar datos de la API\n  useEffect(() => {\n    const cargarDatos = async () => {\n      setLoading(true);\n      \n      try {\n        // Realizar llamadas a la API\n        const fetchBarcos = fetch(`${API_URL}/api/barcos?puerto=${puertoSeleccionado}`)\n          .then(res => res.json())\n          .catch(err => {\n            console.error("Error al cargar datos de barcos:", err);\n            return null;\n          });\n          \n        const fetchEnvios = fetch(`${API_URL}/api/envios-plantas?periodo=${periodoSeleccionado}`)\n          .then(res => res.json())\n          .catch(err => {\n            console.error("Error al cargar datos de envíos:", err);\n            return null;\n          });\n          \n        const fetchLineup = fetch(`${API_URL}/api/lineup?puerto=${puertoSeleccionado}`)\n          .then(res => res.json())\n          .catch(err => {\n            console.error("Error al cargar datos de lineup:", err);\n            return null;\n          });\n          \n        const fetchIndicadores = fetch(`${API_URL}/api/indicadores`)\n          .then(res => res.json())\n          .catch(err => {\n            console.error("Error al cargar indicadores:", err);\n            return null;\n          });\n        \n        // Esperar a que todas las llamadas terminen\n        const [datosBarcos, datosEnvios, datosLineup, datosIndicadores] = await Promise.all([\n          fetchBarcos, fetchEnvios, fetchLineup, fetchIndicadores\n        ]);\n        \n        // Actualizar estados con los datos obtenidos\n        if (datosBarcos) setDatosBarcos(datosBarcos);\n        if (datosEnvios) setDatosEnvios(datosEnvios);\n        if (datosLineup) setDatosLineup(datosLineup);\n        if (datosIndicadores && datosIndicadores.alertas) setAnomaliasDetectadas(datosIndicadores.alertas);\n        \n        // Si alguna llamada falla, usar datos simulados\n        if (!datosBarcos) {\n          setDatosBarcos({\n            barcoActual: {\n              nombre: "Darya Tiana",\n              carga: "Maíz argentino - Soya",\n              fechaInicio: "07-10-2024 3:20",\n              fechaTermino: "12-10-2024 3:20",\n              puerto: "Puerto San Antonio",\n              cumplimiento: 45,\n              programado: 1234,\n              despachado: 567\n            },\n            proximosBarcos: [\n              { nombre: "Nordic Bulker", carga: "Trigo - Maíz", fechaEstimada: "14-10-2024", puerto: "Puerto San Antonio" },\n              { nombre: "Baltic Carrier", carga: "Soya - Harina", fechaEstimada: "20-10-2024", puerto: "Puert ...
#   'user_id': '71874759-2026-4e9c-8d0e-7456b87f4133'}]

# %% [markdown]
# ## Artifact nodes creation from Supabase data

# %%
def exec(date):
    try:
        artifacts = get_artifacts_from_supabase(date=date)
        print(f"Se encontraron {len(artifacts)} artifacts en Supabase.")
    except Exception as e:
        print(f"Error al obtener artifacts: {e}")
        return

    for artifact in artifacts:
        print(f"Procesando artifact con ID: {artifact['id']}")
        artifact_code = artifact["code"]
        artifact_user = artifact["user_id"]
        process_result = process_artifact(artifact_code, artifact_user)
        print(f"Resultado para el artifact con ID {artifact['id']} y usuario {artifact_user}:")
        print(f"  - ID del artifact procesado: {process_result['artifact_id']}")
        print(f"  - Mensaje: {process_result['message']}")
        print(f"  - Nodos insertados: {process_result['nodes_inserted']}")
        print(f"  - Relaciones insertadas: {process_result['relationships_inserted']}")
        print("-" * 50)
    
    return

if __name__ == "__main__":
    extract_date = "2025-04-01"
    exec(extract_date)
# Out:
# Se encontraron 6 artifacts en Supabase.
# Procesando artifact con ID: 47a81ad7-b98d-41cf-aa86-087e164d5aa9
# [Paso 1] Recibiendo el código del artifact...
# [Paso 2] Extrayendo información del código...
# [Neo4j] Extrayendo información del código... (Intento 1)
# [Warning] No se encontraron entidades en este intento.
# [Neo4j] Extrayendo información del código... (Intento 2)
# [Warning] No se encontraron entidades en este intento.
# [Error] No se encontraron entidades después de varios intentos.
# APIs detectadas: []
# Endpoints detectados: []
# Bases de datos detectadas: []
# Consultas SQL detectadas: []
# Tablas detectadas: []
# Relaciones detectadas: relaciones=[]
# [Paso 3] Generando contexto de negocio para APIs, Endpoints, Bases de Datos, KPIs y Estadísticas...
# [Paso 4] Generando nodos a partir de las entidades extraídas...
# [Paso 5] Obteniendo nodos existentes de la base...
# [Paso 6] Evaluando relaciones entre todos los nodos...
# [Paso 7] Insertando nodos y relaciones en Neo4j...
# [Neo4j] Inserting nodes...
# [Neo4j] Inserting relationships...
# [Neo4j] Data inserted successfully.
# [Neo4j] Creando relaciones del Artifact con nodos válidos...
# [Neo4j] Relaciones del Artifact insertadas correctamente.
# [Neo4j] Creando relación Usuario-Artifact...
# [Neo4j] Relación Usuario-Artifact insertada correctamente.
# Resultado para el artifact con ID 47a81ad7-b98d-41cf-aa86-087e164d5aa9 y usuario 71874759-2026-4e9c-8d0e-7456b87f4133:
#   - ID del artifact procesado: 9321a29c-d7c6-4b5f-817b-668c273e30e9
#   - Mensaje: Artifact processed successfully
#   - Nodos insertados: 0
#   - Relaciones insertadas: 0
# --------------------------------------------------
# Procesando artifact con ID: e273da21-7abf-4723-8a5e-5dcd5a2a2d6b
# [Paso 1] Recibiendo el código del artifact...
# [Paso 2] Extrayendo información del código...
# [Neo4j] Extrayendo información del código... (Intento 1)
# APIs detectadas: [APINode(id='api_1', name='Memgraph API', description='API for retrieving sector information', base_url='https://api-memgraph.replit.app')]
# Endpoints detectados: [EndpointNode(id='endpoint_1', api_id='api_1', path='/api/sectors', method='GET', parameters=[], description='Fetches sector data')]
# Bases de datos detectadas: []
# Consultas SQL detectadas: []
# Tablas detectadas: []
# Relaciones detectadas: relaciones=[]
# [Paso 3] Generando contexto de negocio para APIs, Endpoints, Bases de Datos, KPIs y Estadísticas...
# [Paso 4] Generando nodos a partir de las entidades extraídas...
# [Paso 5] Obteniendo nodos existentes de la base...
# [Paso 6] Evaluando relaciones entre todos los nodos...
# [Paso 7] Insertando nodos y relaciones en Neo4j...
# [Neo4j] Inserting nodes...
# [Neo4j] Inserting relationships...
# [Neo4j] Data inserted successfully.
# [Neo4j] Creando relaciones del Artifact con nodos válidos...
# [Neo4j] Relaciones del Artifact insertadas correctamente.
# [Neo4j] Creando relación Usuario-Artifact...
# [Neo4j] Relación Usuario-Artifact insertada correctamente.
# Resultado para el artifact con ID e273da21-7abf-4723-8a5e-5dcd5a2a2d6b y usuario 71874759-2026-4e9c-8d0e-7456b87f4133:
#   - ID del artifact procesado: 09f8bf42-1cf2-4c98-8c93-786dbbc2a557
#   - Mensaje: Artifact processed successfully
#   - Nodos insertados: 2
#   - Relaciones insertadas: 1
# --------------------------------------------------
# Procesando artifact con ID: 5d2ce1e4-3a63-4560-a034-07dfc327b5c1
# [Paso 1] Recibiendo el código del artifact...
# [Paso 2] Extrayendo información del código...
# [Neo4j] Extrayendo información del código... (Intento 1)
# APIs detectadas: [APINode(id='api_1', name='Memgraph KPIs API', description='API for retrieving KPIs data', base_url='https://api-memgraph.replit.app')]
# Endpoints detectados: [EndpointNode(id='endpoint_1', api_id='api_1', path='/api/kpis', method='GET', parameters=[], description='Fetch KPIs data')]
# Bases de datos detectadas: []
# Consultas SQL detectadas: []
# Tablas detectadas: []
# Relaciones detectadas: relaciones=[]
# [Paso 3] Generando contexto de negocio para APIs, Endpoints, Bases de Datos, KPIs y Estadísticas...
# [Paso 4] Generando nodos a partir de las entidades extraídas...
# [Paso 5] Obteniendo nodos existentes de la base...
# [Paso 6] Evaluando relaciones entre todos los nodos...
# [Paso 7] Insertando nodos y relaciones en Neo4j...
# [Neo4j] Inserting nodes...
# [Neo4j] Inserting relationships...
# [Neo4j] Data inserted successfully.
# [Neo4j] Creando relaciones del Artifact con nodos válidos...
# [Neo4j] Relaciones del Artifact insertadas correctamente.
# [Neo4j] Creando relación Usuario-Artifact...
# [Neo4j] Relación Usuario-Artifact insertada correctamente.
# Resultado para el artifact con ID 5d2ce1e4-3a63-4560-a034-07dfc327b5c1 y usuario 71874759-2026-4e9c-8d0e-7456b87f4133:
#   - ID del artifact procesado: 571d096e-da5c-4764-ad75-8215e6f0a298
#   - Mensaje: Artifact processed successfully
#   - Nodos insertados: 2
#   - Relaciones insertadas: 1
# --------------------------------------------------
# Procesando artifact con ID: 447b3c24-9622-4b96-b1df-52d5158a2212
# [Paso 1] Recibiendo el código del artifact...
# [Paso 2] Extrayendo información del código...
# [Neo4j] Extrayendo información del código... (Intento 1)
# [Warning] No se encontraron entidades en este intento.
# [Neo4j] Extrayendo información del código... (Intento 2)
# [Warning] No se encontraron entidades en este intento.
# [Error] No se encontraron entidades después de varios intentos.
# APIs detectadas: []
# Endpoints detectados: []
# Bases de datos detectadas: []
# Consultas SQL detectadas: []
# Tablas detectadas: []
# Relaciones detectadas: relaciones=[]
# [Paso 3] Generando contexto de negocio para APIs, Endpoints, Bases de Datos, KPIs y Estadísticas...
# [Paso 4] Generando nodos a partir de las entidades extraídas...
# [Paso 5] Obteniendo nodos existentes de la base...
# [Paso 6] Evaluando relaciones entre todos los nodos...
# [Paso 7] Insertando nodos y relaciones en Neo4j...
# [Neo4j] Inserting nodes...
# [Neo4j] Inserting relationships...
# [Neo4j] Data inserted successfully.
# [Neo4j] Creando relaciones del Artifact con nodos válidos...
# [Neo4j] Relaciones del Artifact insertadas correctamente.
# [Neo4j] Creando relación Usuario-Artifact...
# [Neo4j] Relación Usuario-Artifact insertada correctamente.
# Resultado para el artifact con ID 447b3c24-9622-4b96-b1df-52d5158a2212 y usuario 71874759-2026-4e9c-8d0e-7456b87f4133:
#   - ID del artifact procesado: 399e5b30-bebf-48fd-86e8-42753e33f77a
#   - Mensaje: Artifact processed successfully
#   - Nodos insertados: 0
#   - Relaciones insertadas: 0
# --------------------------------------------------
# Procesando artifact con ID: 3457310a-861f-4e0f-9166-2d20aa6acbd0
# [Paso 1] Recibiendo el código del artifact...
# [Paso 2] Extrayendo información del código...
# [Neo4j] Extrayendo información del código... (Intento 1)
# APIs detectadas: [APINode(id='api_1', name='Control Tower API', description='API for monitoring plant performance and stock levels', base_url='https://api-control-tower.replit.app')]
# Endpoints detectados: [EndpointNode(id='endpoint_1', api_id='api_1', path='/api/rendimiento-plantas', method='GET', parameters=[], description='Fetches performance data for plants'), EndpointNode(id='endpoint_2', api_id='api_1', path='/api/stock-plantas', method='GET', parameters=[], description='Fetches stock data for plants'), EndpointNode(id='endpoint_3', api_id='api_1', path='/api/cumplimiento-despacho', method='GET', parameters=[], description='Fetches dispatch compliance data'), EndpointNode(id='endpoint_4', api_id='api_1', path='/api/cumplimiento-entrega', method='GET', parameters=[], description='Fetches delivery compliance data')]
# Bases de datos detectadas: []
# Consultas SQL detectadas: []
# Tablas detectadas: []
# Relaciones detectadas: relaciones=[]
# [Paso 3] Generando contexto de negocio para APIs, Endpoints, Bases de Datos, KPIs y Estadísticas...
# [Paso 4] Generando nodos a partir de las entidades extraídas...
# [Paso 5] Obteniendo nodos existentes de la base...
# [Paso 6] Evaluando relaciones entre todos los nodos...
# [Paso 7] Insertando nodos y relaciones en Neo4j...
# [Neo4j] Inserting nodes...
# [Neo4j] Inserting relationships...
# [Neo4j] Data inserted successfully.
# [Neo4j] Creando relaciones del Artifact con nodos válidos...
# [Neo4j] Relaciones del Artifact insertadas correctamente.
# [Neo4j] Creando relación Usuario-Artifact...
# [Neo4j] Relación Usuario-Artifact insertada correctamente.
# Resultado para el artifact con ID 3457310a-861f-4e0f-9166-2d20aa6acbd0 y usuario 71874759-2026-4e9c-8d0e-7456b87f4133:
#   - ID del artifact procesado: dd8a00b9-9af1-4bee-b6c7-847e6bd684f8
#   - Mensaje: Artifact processed successfully
#   - Nodos insertados: 5
#   - Relaciones insertadas: 4
# --------------------------------------------------
# Procesando artifact con ID: 9648cadb-becb-4b7c-b264-ba49e250971b
# [Paso 1] Recibiendo el código del artifact...
# [Paso 2] Extrayendo información del código...
# [Neo4j] Extrayendo información del código... (Intento 1)
# APIs detectadas: [APINode(id='api_1', name='Control Tower API', description='API for managing and monitoring port operations and logistics', base_url='https://api-control-tower.replit.app')]
# Endpoints detectados: [EndpointNode(id='endpoint_1', api_id='api_1', path='/api/barcos', method='GET', parameters=['puerto'], description='Fetch ship data for a specific port.'), EndpointNode(id='endpoint_2', api_id='api_1', path='/api/envios-plantas', method='GET', parameters=['periodo'], description='Fetch shipment data for plants by a specific period.'), EndpointNode(id='endpoint_3', api_id='api_1', path='/api/lineup', method='GET', parameters=['puerto'], description='Fetch lineup data for a specific port.'), EndpointNode(id='endpoint_4', api_id='api_1', path='/api/indicadores', method='GET', parameters=[], description='Fetch logistic indicators.'), EndpointNode(id='endpoint_5', api_id='api_1', path='/api/simulacion', method='POST', parameters=['JSON object with simulation parameters'], description='Post simulation scenario for logistic operations.')]
# Bases de datos detectadas: []
# Consultas SQL detectadas: []
# Tablas detectadas: []
# Relaciones detectadas: relaciones=[]
# [Paso 3] Generando contexto de negocio para APIs, Endpoints, Bases de Datos, KPIs y Estadísticas...
# [Paso 4] Generando nodos a partir de las entidades extraídas...
# [Paso 5] Obteniendo nodos existentes de la base...
# [Paso 6] Evaluando relaciones entre todos los nodos...
# [Paso 7] Insertando nodos y relaciones en Neo4j...
# [Neo4j] Inserting nodes...
# [Neo4j] Inserting relationships...
# [Neo4j] Data inserted successfully.
# [Neo4j] Creando relaciones del Artifact con nodos válidos...
# [Neo4j] Relaciones del Artifact insertadas correctamente.
# [Neo4j] Creando relación Usuario-Artifact...
# [Neo4j] Relación Usuario-Artifact insertada correctamente.
# Resultado para el artifact con ID 9648cadb-becb-4b7c-b264-ba49e250971b y usuario 71874759-2026-4e9c-8d0e-7456b87f4133:
#   - ID del artifact procesado: a451d998-62c8-4097-9564-f8a9f4f55176
#   - Mensaje: Artifact processed successfully
#   - Nodos insertados: 6
#   - Relaciones insertadas: 5
# --------------------------------------------------
